# %% [markdown]
# # Part 1: Data Munging
#
# Given two data files, your first task is to standardize and combine them into a common file for further analysis.
#
# Steps:
# 1. Transform us_softball_league.tsv to match unity_golf_club.csv in columns and format.
#     - Standardize first and last name columns.
#     - Convert dates into a common format.
#     - All states should be in two character abbreviation.
# 2. Combine the two files into one master file.
#     - Indicate the source file for each record in the combined file.
# 3. Use companies.csv to replace `company_id` with the company name.
# 4. Identify suspect records (hint: look for impossible chronological combinations).
#     - Write bad records into a separate file.
#     - Drop those records from the main file.

# %%
# 1. Transform us_softball_league.tsv to match unity_golf_club.csv in columns and format.
#   - Standardize first and last name columns.
#   - Convert dates into a common format.
#  - All states should be in two character abbreviation.

# %%
import pandas as pd

# %%
us_softball_n = pd.read_csv('us_softball_league.tsv', sep='\t')

# %%
us_softball_n
# Out:
#                    name date_of_birth  company_id last_active  score  \
# 0       Mikayla Brennan    11/02/1966           2  07/04/2018     84
# 1         Thomas Holmes    11/29/1962           1  05/15/2018     92
# 2           Corey Jones    12/20/1964           7  08/25/2018     47
# 3          Laura Howard    04/26/1989           8  04/15/2018     76
# 4     Daniel Mclaughlin    06/19/1966          13  05/10/2018     56
# ...                 ...           ...         ...         ...    ...
# 7647         John Lopez    02/19/1985           5  07/31/2018     95
# 7648       Janice Perez    03/28/1968           4  11/25/2018     88
# 7649      Deborah Walls    11/22/1993          15  08/04/2018     87
# 7650  Michael Schneider    06/26/1997           5  08/22/2018     44
# 7651      Bradley Horne    07/08/1972           6  01/08/2019     92
#
#       joined_league        us_state
# 0              1989        Illinois
# 1              1972       Wisconsin
# 2              2007      New Mexico
# 3              1976      New Jersey
# 4              1986    Rhode Island
# ...             ...             ...
# 7647           1975        Virginia
# 7648           1994         Vermont
# 7649           1994  South Carolina
# 7650           2007         Arizona
# 7651           1980            Ohio
#
# [7652 rows x 7 columns]

# %% [markdown]
# # Standardize first and last name columns

# %%
us_softball_n['first_name'] = us_softball_n['name'].apply(lambda x: x.split()[0])

# %%
us_softball_n['last_name'] = us_softball_n['name'].apply(lambda x: x.split()[1])

# %%
us_softball_n
# Out:
#                    name date_of_birth  company_id last_active  score  \
# 0       Mikayla Brennan    11/02/1966           2  07/04/2018     84
# 1         Thomas Holmes    11/29/1962           1  05/15/2018     92
# 2           Corey Jones    12/20/1964           7  08/25/2018     47
# 3          Laura Howard    04/26/1989           8  04/15/2018     76
# 4     Daniel Mclaughlin    06/19/1966          13  05/10/2018     56
# ...                 ...           ...         ...         ...    ...
# 7647         John Lopez    02/19/1985           5  07/31/2018     95
# 7648       Janice Perez    03/28/1968           4  11/25/2018     88
# 7649      Deborah Walls    11/22/1993          15  08/04/2018     87
# 7650  Michael Schneider    06/26/1997           5  08/22/2018     44
# 7651      Bradley Horne    07/08/1972           6  01/08/2019     92
#
#       joined_league        us_state first_name   last_name
# 0              1989        Illinois    Mikayla     Brennan
# 1              1972       Wisconsin     Thomas      Holmes
# 2              2007      New Mexico      Corey       Jones
# 3              1976      New Jersey      Laura      Howard
# 4              1986    Rhode Island     Daniel  Mclaughlin
# ...             ...             ...        ...         ...
# 7647           1975        Virginia       John       Lopez
# 7648           1994         Vermont     Janice       Perez
# 7649           1994  South Carolina    Deborah       Walls
# 7650           2007         Arizona    Michael   Schneider
# 7651           1980            Ohio    Bradley       Horne
#
# [7652 rows x 9 columns]

# %% [markdown]
# # rearrange the columns
# us_softball_n = us_softball_n[[ 'first_name', 'last_name', 'date_of_birth', 'company_id', 'last_active', 'score', 'joined_league', 'us_state']]

# %%
us_softball_n = us_softball_n[[ 'first_name', 'last_name', 'date_of_birth', 'company_id', 'last_active', 'score', 'joined_league', 'us_state']]

# %%
us_softball_n.head(3)
# Out:
#   first_name last_name date_of_birth  company_id last_active  score  \
# 0    Mikayla   Brennan    11/02/1966           2  07/04/2018     84
# 1     Thomas    Holmes    11/29/1962           1  05/15/2018     92
# 2      Corey     Jones    12/20/1964           7  08/25/2018     47
#
#    joined_league    us_state
# 0           1989    Illinois
# 1           1972   Wisconsin
# 2           2007  New Mexico

# %% [markdown]
# # #   - Convert dates into a common format.

# %%
us_softball_n['date_of_birth'] = pd.to_datetime(us_softball_n['date_of_birth'], format='%m-%d-%Y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:510, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     509 try:
# --> 510     values, tz = conversion.datetime_to_datetime64(arg)
#     511     dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 us_softball_n['date_of_birth'] = pd.to_datetime(us_softball_n['date_of_birth'], format='%m-%d-%Y')
#
# File ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1051, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1049         result = arg.map(cache_array)
#    1050     else:
# -> 1051         values = convert_listlike(arg._values, format)
#    1052         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1053 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:394, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     391         format = None
#     393 if format is not None:
# --> 394     res = _to_datetime_with_format(
#     395         arg, orig_arg, name, tz, format, exact, errors, infer_datetime_format
#     396     )
#     397     if res is not None:
#     398         return res
#
# File ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:514, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     512     return DatetimeIndex._simple_new(dta, name=name)
#     513 except (ValueError, TypeError):
# --> 514     raise err
#
# File ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:501, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     498             return _box_as_indexlike(result, utc=utc, name=name)
#     500     # fallback
# --> 501     res = _array_strptime_with_fallback(
#     502         arg, name, tz, fmt, exact, errors, infer_datetime_format
#     503     )
#     504     return res
#     506 except ValueError as err:
#     507     # Fallback to try to convert datetime objects if timezone-aware
#     508     #  datetime objects are found without passing `utc=True`
#
# File ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:437, in _array_strptime_with_fallback(arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     434 utc = tz == "utc"
#     436 try:
# --> 437     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors)
#     438     if "%Z" in fmt or "%z" in fmt:
#     439         return _return_parsed_timezone_results(result, timezones, tz, name)
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\strptime.pyx:150, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data '11/02/1966' does not match format '%m-%d-%Y' (match)

# %%
us_softball_n = us_softball_n.copy()

# %%
us_softball_n['date_of_birth'] = pd.to_datetime(us_softball_n['date_of_birth'], format='%m/%d/%Y')

# %%
us_softball_n.head(5)
# Out:
#   first_name   last_name date_of_birth  company_id last_active  score  \
# 0    Mikayla     Brennan    1966-11-02           2  07/04/2018     84
# 1     Thomas      Holmes    1962-11-29           1  05/15/2018     92
# 2      Corey       Jones    1964-12-20           7  08/25/2018     47
# 3      Laura      Howard    1989-04-26           8  04/15/2018     76
# 4     Daniel  Mclaughlin    1966-06-19          13  05/10/2018     56
#
#    joined_league      us_state
# 0           1989      Illinois
# 1           1972     Wisconsin
# 2           2007    New Mexico
# 3           1976    New Jersey
# 4           1986  Rhode Island

# %%
us_softball_n['last_active'] = pd.to_datetime(us_softball_n['last_active'], format='%m/%d/%Y')

# %%
us_softball_n.head(5)
# Out:
#   first_name   last_name date_of_birth  company_id last_active  score  \
# 0    Mikayla     Brennan    1966-11-02           2  2018-07-04     84
# 1     Thomas      Holmes    1962-11-29           1  2018-05-15     92
# 2      Corey       Jones    1964-12-20           7  2018-08-25     47
# 3      Laura      Howard    1989-04-26           8  2018-04-15     76
# 4     Daniel  Mclaughlin    1966-06-19          13  2018-05-10     56
#
#    joined_league      us_state
# 0           1989      Illinois
# 1           1972     Wisconsin
# 2           2007    New Mexico
# 3           1976    New Jersey
# 4           1986  Rhode Island

# %% [markdown]
# # - All states should be in two character abbreviation.

# %%
# !pip install us
# Out:
# Requirement already satisfied: us in c:\users\gn\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: jellyfish==0.6.1 in c:\users\gn\anaconda3\lib\site-packages (from us) (0.6.1)

# %%
import us

# %%
us_softball_n['us_states_abb'] = us_softball_n['us_state'].apply(lambda x: us.states.lookup(x).abbr)

# %%
us_softball_n.head(4)
# Out:
#   first_name last_name date_of_birth  company_id last_active  score  \
# 0    Mikayla   Brennan    1966-11-02           2  2018-07-04     84
# 1     Thomas    Holmes    1962-11-29           1  2018-05-15     92
# 2      Corey     Jones    1964-12-20           7  2018-08-25     47
# 3      Laura    Howard    1989-04-26           8  2018-04-15     76
#
#    joined_league    us_state us_states_abb
# 0           1989    Illinois            IL
# 1           1972   Wisconsin            WI
# 2           2007  New Mexico            NM
# 3           1976  New Jersey            NJ

# %%
us_softball_n.head(3)
# Out:
#   first_name last_name date_of_birth  company_id last_active  score  \
# 0    Mikayla   Brennan    1966-11-02           2  2018-07-04     84
# 1     Thomas    Holmes    1962-11-29           1  2018-05-15     92
# 2      Corey     Jones    1964-12-20           7  2018-08-25     47
#
#    joined_league    us_state us_states_abb
# 0           1989    Illinois            IL
# 1           1972   Wisconsin            WI
# 2           2007  New Mexico            NM

# %%
us_softball_n.isnull().sum()
# Out:
# first_name       0
# last_name        0
# date_of_birth    0
# company_id       0
# last_active      0
# score            0
# joined_league    0
# us_states_abb    0
# dtype: int64

# %% [markdown]
# # Combine the two files into one master file.

# %%
unity_golf_n = pd.read_csv('unity_golf_club.csv')

# %%
unity_golf_n.isnull().sum()
# Out:
# first_name      0
# last_name       0
# dob             0
# company_id      0
# last_active     0
# score           0
# member_since    0
# state           0
# dtype: int64

# %%
unity_golf_n.head(3)
# Out:
#   first_name   last_name         dob  company_id last_active  score  \
# 0     Robert  Mclaughlin  1967/03/26           3  2018/08/25     57
# 1   Brittany      Norris  1972/09/06          12  2018/03/29     73
# 2     Sharon     Nichols  1971/04/19           7  2018/04/11     92
#
#    member_since state
# 0          2013    OR
# 1          1986    MD
# 2          1985    WY

# %%
master_file = pd.concat([us_softball_n,unity_golf_n], axis=0)

# %%
master_file.head(3)
# Out:
#   first_name last_name date_of_birth  company_id          last_active  score  \
# 0    Mikayla   Brennan    1966-11-02           2  2018-07-04 00:00:00     84
# 1     Thomas    Holmes    1962-11-29           1  2018-05-15 00:00:00     92
# 2      Corey     Jones    1964-12-20           7  2018-08-25 00:00:00     47
#
#    joined_league    us_state us_states_abb  dob  member_since state
# 0         1989.0    Illinois            IL  NaN           NaN   NaN
# 1         1972.0   Wisconsin            WI  NaN           NaN   NaN
# 2         2007.0  New Mexico            NM  NaN           NaN   NaN

# %%
master_file.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Use companies.csv to replace `company_id` with the company name.

# %%
companies_n = pd.read_csv('companies.csv')

# %%
companies_n.head(3)
# Out:
#    id                        name
# 0   0         Williams-Stephenson
# 1   1  Brown, Vasquez and Sanchez
# 2   2                Keller Group

# %%
master_file= master_file.join(companies_n, on='company_id', how='outer')

# %%
master_file.head(3)
# Out:
#    first_name last_name date_of_birth  company_id          last_active  score  \
# 0     Mikayla   Brennan    1966-11-02           2  2018-07-04 00:00:00     84
# 7         Don   Johnson    1962-05-02           2  2018-11-17 00:00:00     56
# 46    Monique     Owens    1982-03-04           2  2018-11-06 00:00:00     89
#
#     joined_league   us_state us_states_abb  dob  member_since state   id  \
# 0          1989.0   Illinois            IL  NaN           NaN   NaN  2.0
# 7          1980.0    Indiana            IN  NaN           NaN   NaN  2.0
# 46         1989.0  Tennessee            TN  NaN           NaN   NaN  2.0
#
#             name
# 0   Keller Group
# 7   Keller Group
# 46  Keller Group

# %% [markdown]
# # Write bad records into a separate file.

# %%
master_file["bad_records"].sum()
# Out:
# 1547

# %%
 master_file['date_of_birth'] =pd.to_datetime(master_file['date_of_birth'])

# %%
master_file["bad_records"] = master_file['date_of_birth'].dt.year > master_file['joined_league']

# %%
bad_records = master_file['date_of_birth'].dt.year > master_file['joined_league']

# %%
bad_records_df = master_file[master_file['bad_records']]

# %%
bad_records.to_csv('bad_record_file1.csv', index = False)

# %%
master_file = master_file[master_file["bad_records"] != True]

# %%
master_file["bad_records"].sum()
# Out:
# 0

# %%
master_file
# Out:
#       first_name  last_name date_of_birth  company_id          last_active  \
# 0        Mikayla    Brennan    1966-11-02           2  2018-07-04 00:00:00
# 7            Don    Johnson    1962-05-02           2  2018-11-17 00:00:00
# 46       Monique      Owens    1982-03-04           2  2018-11-06 00:00:00
# 49       Richard     Carter    1965-05-22           2  2018-12-04 00:00:00
# 65       Heather      Davis    1987-05-19           2  2018-03-11 00:00:00
# ...          ...        ...           ...         ...                  ...
# 8390     Felicia      Burch           NaT           9           2018/04/28
# 8404       Jacob     Moreno           NaT           9           2018/07/06
# 8417      Evelyn  Velazquez           NaT           9           2018/01/30
# 8458  Alexandria  Daugherty           NaT           9           2018/08/18
# 8460    Samantha       Soto           NaT           9           2018/07/10
#
#       score  joined_league    us_state us_states_abb         dob  \
# 0        84         1989.0    Illinois            IL         NaN
# 7        56         1980.0     Indiana            IN         NaN
# 46       89         1989.0   Tennessee            TN         NaN
# 49       89         1986.0       Maine            ME         NaN
# 65       51         2008.0  Washington            WA         NaN
# ...     ...            ...         ...           ...         ...
# 8390     64            NaN         NaN           NaN  1985/10/10
# 8404     85            NaN         NaN           NaN  1972/07/20
# 8417     65            NaN         NaN           NaN  1960/02/11
# 8458     78            NaN         NaN           NaN  1990/08/26
# 8460     80            NaN         NaN           NaN  1989/12/01
#
#       member_since state   id                        name  bad_records
# 0              NaN   NaN  2.0                Keller Group        False
# 7              NaN   NaN  2.0                Keller Group        False
# 46             NaN   NaN  2.0                Keller Group        False
# 49             NaN   NaN  2.0                Keller Group        False
# 65             NaN   NaN  2.0                Keller Group        False
# ...            ...   ...  ...                         ...          ...
# 8390        1990.0    IN  9.0  Martin, Mcknight and Clark        False
# 8404        1983.0    VT  9.0  Martin, Mcknight and Clark        False
# 8417        2015.0    DC  9.0  Martin, Mcknight and Clark        False
# 8458        1999.0    MN  9.0  Martin, Mcknight and Clark        False
# 8460        1981.0    NC  9.0  Martin, Mcknight and Clark        False
#
# [14571 rows x 15 columns]

# %% [markdown]
# # Part 2: Ingestion System

# %%
# writing data to sqlite database

# %%
connection = sqlite.connect(transformed_masterfile_database)

# %%
master_file.to_sql("master_file_table", connection , index = False )
connection.close()

# %% [markdown]
# # Part 3: Follow-up

# %%
# 1) we can  furter clean this dataset like bad recordes 
# 2) we can clear unwanted columns 
# 3) concat the columns 
# 4) we can  furter clean this dataset
# 5) handling the missing values such as dropping or filling
# 6) handling incosistent capitalization
